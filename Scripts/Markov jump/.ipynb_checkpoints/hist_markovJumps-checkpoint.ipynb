# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
clade21 = pd.read_csv('WAI_data/2.3.2.1fAreaDTA_MJs_bi.txt')
clade34 = pd.read_csv('WAI_data/2.3.4.4fAreaDTA_MJs_bi.txt')

# %%
clade21['dateinyear'] = clade21['date'] - np.floor(clade21['date'])
clade34['dateinyear'] = clade34['date'] - np.floor(clade34['date'])

# %%
clade21['od'] = clade21['origin'] + '-' + clade21['destination']
clade34['od'] = clade34['origin'] + '-' + clade34['destination']

# %% [markdown]
# ### Disribution of earliest virus lineage migration event in a year

# %%
clade21_mindatInYr = clade21.groupby(['treeNumber','od'])['dateinyear'].min().reset_index()
clade21_mindatInYr['days']=clade21_mindatInYr['dateinyear']*365
clade21_mindatInYr = clade21_mindatInYr.sort_values('od')

# %%
clade21_mindatInYr.groupby(['od'])['days'].describe(percentiles=[.025, .25, .5, .75, .975])
# Out:
#                     count        mean         std        min       2.5%  \
# od
# Africa-CA            20.0  218.397614  108.932764   7.034613  19.172533
# Africa-Europe       203.0  155.778372  111.636926   0.328294   2.802227
# Africa-JapanKorea    12.0  189.052525  107.037973  40.627838  57.475900
# Africa-Mongolia      25.0  193.132157  115.101495  22.626975  26.415702
# Africa-NChina        49.0  198.186907  106.015153   1.898860   6.811732
# ...                   ...         ...         ...        ...        ...
# WA-NChina           283.0  192.900244  110.800462   0.421910   7.385057
# WA-Qinghai          203.0  185.863500  106.845209   1.644914  14.427782
# WA-Russia          1581.0  171.712519  105.572368   0.208636   8.563149
# WA-SChina            70.0  189.588638  100.732555   0.115495   6.558937
# WA-SEA                5.0  207.561362  180.935973   5.757274   6.633345
#
#                           25%         50%         75%       97.5%         max
# od
# Africa-CA          140.659791  220.710038  310.871581  354.160912  355.510439
# Africa-Europe       62.255116  121.171832  254.024700  351.270389  363.315113
# Africa-JapanKorea  105.975384  147.636283  280.257254  347.131940  355.616773
# Africa-Mongolia     73.809837  218.509849  287.238267  347.158744  357.082164
# Africa-NChina       98.908988  238.597444  283.897237  347.422061  352.831061
# ...                       ...         ...         ...         ...         ...
# WA-NChina           89.412763  208.793362  291.533998  358.969900  364.763310
# WA-Qinghai          87.810323  196.315843  278.817479  357.281813  364.063244
# WA-Russia           79.386081  163.788338  258.726909  353.833569  364.944980
# WA-SChina          114.843714  210.817649  269.945818  350.568380  364.352062
# WA-SEA              14.517989  320.561289  333.111919  360.783700  363.858342
#
# [110 rows x 10 columns]

# %%
fig21 = plt.figure(figsize=(30, 6))
plt.xticks(rotation=90)
bwp_21 = sns.boxplot(
    x="od", y="days", 
    data=clade21_mindatInYr, whis=[2.5,97.5])
plt.xlabel('Origin - Destination of virus lineage migration event',fontsize=12)
plt.ylabel('Earliest migration date (days in a year)',fontsize=12)
plt.tight_layout()
fig21.savefig('output/clade2.3.2.1_earliest_jumps.jpg')

# %%
clade34_mindatInYr = clade34.groupby(['treeNumber','od'])['dateinyear'].min().reset_index()
clade34_mindatInYr['days']=clade34_mindatInYr['dateinyear']*365
clade34_mindatInYr = clade34_mindatInYr.sort_values('od')

# %%
clade34_mindatInYr.groupby(['od'])['days'].describe(percentiles=[.025, .25, .5, .75, .975])
# Out:
#                        count        mean         std        min        2.5%  \
# od
# Africa-CA              151.0  244.563603   43.407562  72.608545  141.833783
# Africa-Europe          268.0  204.049548  108.913608   0.141328    3.235859
# Africa-JapanKorea      489.0  289.027756   41.260431  10.056292  172.032734
# Africa-NChina           20.0  179.573308  112.546800   3.448622   11.657323
# Africa-Qinghai         229.0   91.252622  118.705808   0.040494    2.453267
# ...                      ...         ...         ...        ...         ...
# USAandCanada-NChina    345.0  270.929346   48.644171   2.478700   94.306811
# USAandCanada-Qinghai   106.0  240.279007  101.451433   0.861685    8.635859
# USAandCanada-Russia    107.0  249.862507   75.904679  14.466184   35.699113
# USAandCanada-SChina   2078.0  243.006305   50.324175   0.808996  131.548698
# USAandCanada-SEA        91.0  265.860821   43.482583   4.664520  173.837627
#
#                              25%         50%         75%       97.5%  \
# od
# Africa-CA             226.760984  254.629146  277.616010  289.796729
# Africa-Europe         122.186806  225.607215  300.487284  351.895060
# Africa-JapanKorea     278.273301  299.494257  315.270305  334.069943
# Africa-NChina          55.640716  188.722104  277.483899  324.041928
# Africa-Qinghai         23.191795   41.669821   65.151114  359.523188
# ...                          ...         ...         ...         ...
# USAandCanada-NChina   264.685730  281.931117  296.622610  316.542149
# USAandCanada-Qinghai  261.536155  278.650808  293.525972  337.894383
# USAandCanada-Russia   258.769384  275.471560  289.605118  313.988076
# USAandCanada-SChina   214.955249  253.132575  280.210559  308.369064
# USAandCanada-SEA      252.931429  277.497044  291.796807  307.573408
#
#                              max
# od
# Africa-CA             291.576292
# Africa-Europe         361.970111
# Africa-JapanKorea     342.794283
# Africa-NChina         324.354873
# Africa-Qinghai        364.400012
# ...                          ...
# USAandCanada-NChina   351.021542
# USAandCanada-Qinghai  361.237343
# USAandCanada-Russia   344.640916
# USAandCanada-SChina   352.036107
# USAandCanada-SEA      315.860477
#
# [90 rows x 10 columns]

# %%
fig34 = plt.figure(figsize=(30, 6))
plt.xticks(rotation=90)
bwp_34 = sns.boxplot(
    x="od", y="days", 
    data=clade34_mindatInYr, whis=[2.5,97.5])
plt.xlabel('Origin - Destination of virus lineage migration event',fontsize=12)
plt.ylabel('Earliest migration date (days in a year)',fontsize=12)
plt.tight_layout()
fig34.savefig('output/clade2.3.4.4_earliest_jumps.jpg')

# %% [markdown]
# ### Virus lineage migration distributover months

# %%
from scipy import stats

# %%
fig, axes = plt.subplots(11,10,figsize=(80,80),dpi=100,sharex=True, sharey=True)

for i, (ax, od) in enumerate(zip(axes.flatten(), clade21.od.unique())):
    x = clade21.loc[clade21.od==od, 'dateinyear']
    
    res = stats.relfreq(x, numbins=12)
    x_space = res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size,
                                 res.frequency.size)
    ax.bar(x_space,res.frequency,width=res.binsize)
    #ax.hist(x, alpha=0.5, bins=365, density=True, stacked=True, label=od)
    ax.set_title(od)
    ax.set_xlim([x_space.min(), x_space.max()])
    
plt.suptitle('Probability Histogram of date of Markov jump events', y=1.05, size=16)
#ax.set_xlim(0, 1); ax.set_ylim(0, 10);
#plt.tight_layout();
fig.savefig('WAI_data/MJ_Dis_Clade2.3.2.1_monthly.pdf')   # save the figure to file
plt.close(fig)    # close the figure window

# %%
fig2, axes2 = plt.subplots(10,9,figsize=(80,80),dpi=100,sharex=True, sharey=True)

for i, (ax, od) in enumerate(zip(axes2.flatten(), clade34.od.unique())):
    x = clade34.loc[clade34.od==od, 'dateinyear']
    
    res = stats.relfreq(x, numbins=12)
    x_space = res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size,
                                 res.frequency.size)
    ax.bar(x_space,res.frequency,width=res.binsize)
    #ax.hist(x, alpha=0.5, bins=365, density=True, stacked=True, label=od)
    ax.set_title(od)
    ax.set_xlim([x_space.min(), x_space.max()])
    
plt.suptitle('Probability Histogram of date of Markov jump events', y=1.05, size=16)
#ax.set_xlim(0, 1); ax.set_ylim(0, 10);
fig2.savefig('WAI_data/MJ_Dis_Clade2.3.4.4_monthly2.pdf')   # save the figure to file
plt.close(fig2)    # close the figure window

# %%
fig, axes = plt.subplots(4,3,figsize=(10,10),dpi=100,sharex=True, sharey=True)

for i, (ax, origin) in enumerate(zip(axes.flatten(), clade21.origin.unique())):
    x = clade21.loc[clade21.origin==origin, 'dateinyear']
    
    #res = stats.relfreq(x, numbins=12)
    #x_space = res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size,
    #                             res.frequency.size)
    #ax.bar(x_space,res.frequency,width=res.binsize)
    ax.hist(x, alpha=0.5, bins=12, density=True, stacked=True, label=origin, edgecolor='black')
    ax.set_xlim(0, 1)
    ax.set_title('Markov jump from ' + origin)
    ax.set_ylabel('Frequency density')
    ax.set_xticks([1/12,1/6,1/4,1/3,5/12,1/2,7/12,2/3,3/4,5/6,11/12,1])
    ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],rotation=45)
    
    #ax.set_xlim([x_space.min(), x_space.max()])
    #ax.set_xlim(0,1)
    
plt.tight_layout()
#plt.suptitle('Probability Histogram of date of Markov jump events', y=1.05, size=16)
fig.savefig('WAI_data/MJ_Dis_Clade2.3.2.1_monthly_origin_density.pdf')   # save the figure to file
plt.close(fig)    # close the figure window

# %%
fig, axes = plt.subplots(4,3,figsize=(10,10),dpi=100,sharex=True, sharey=True)

for i, (ax, destination) in enumerate(zip(axes.flatten(), clade21.origin.unique())):
    x = clade21.loc[clade21.destination==destination, 'dateinyear']
    
    #res = stats.relfreq(x, numbins=12)
    #x_space = res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size,
    #                             res.frequency.size)
    #ax.bar(x_space,res.frequency,width=res.binsize)
    ax.hist(x, alpha=0.5, bins=12, density=True, stacked=True, label=destination, edgecolor='black')
    ax.set_title('Markov jump to ' + destination)
    ax.set_ylabel('Frequency density')
    ax.set_xticks([1/12,1/6,1/4,1/3,5/12,1/2,7/12,2/3,3/4,5/6,11/12,1])
    ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],rotation=45)
    #ax.set_xlim([x_space.min(), x_space.max()])
    #ax.set_xlim(0,1)
    
#plt.suptitle('Probability Histogram of date of Markov jump events', y=1.05, size=16)
ax.set_xlim(0, 1); 
plt.tight_layout();
fig.savefig('WAI_data/MJ_Dis_Clade2.3.2.1_monthly_destination_density.pdf')   # save the figure to file
plt.close(fig)    # close the figure window

# %%
fig, axes = plt.subplots(2,5,figsize=(25,10),dpi=100,sharex=True, sharey=True)

for i, (ax, origin) in enumerate(zip(axes.flatten(), clade34.origin.unique())):
    x = clade34.loc[clade34.origin==origin, 'dateinyear']
    
    #res = stats.relfreq(x, numbins=12)
    #x_space = res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size,
    #                             res.frequency.size)
    #ax.bar(x_space,res.frequency,width=res.binsize)
    ax.hist(x, alpha=0.5, bins=12, density=True, stacked=True, label=origin, edgecolor='black')
    ax.set_title('Markov jump from ' + origin)
    ax.set_ylabel('Frequency density')
    ax.set_xticks([1/12,1/6,1/4,1/3,5/12,1/2,7/12,2/3,3/4,5/6,11/12,1])
    ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],rotation=45)
    #ax.set_xlim([x_space.min(), x_space.max()])
    #ax.set_xlim(0,1)
    
#plt.suptitle('Probability Histogram of date of Markov jump events', y=1.05, size=16)
ax.set_xlim(0, 1); 
plt.tight_layout();
fig.savefig('WAI_data/MJ_Dis_Clade2.3.4.4_monthly_origin_density.pdf')   # save the figure to file
plt.close(fig)    # close the figure window

# %%
fig, axes = plt.subplots(2,5,figsize=(25,10),dpi=100,sharex=True, sharey=True)

for i, (ax, destination) in enumerate(zip(axes.flatten(), clade34.destination.unique())):
    x = clade34.loc[clade34.destination==destination, 'dateinyear']
    
    #res = stats.relfreq(x, numbins=12)
    #x_space = res.lowerlimit + np.linspace(0, res.binsize*res.frequency.size,
    #                             res.frequency.size)
    #ax.bar(x_space,res.frequency,width=res.binsize)
    ax.hist(x, alpha=0.5, bins=12, density=True, stacked=True, label=destination, edgecolor='black')
    ax.set_title('Markov jump to ' + destination)
    ax.set_ylabel('Frequency density')
    ax.set_xticks([1/12,1/6,1/4,1/3,5/12,1/2,7/12,2/3,3/4,5/6,11/12,1])
    ax.set_xticklabels(['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],rotation=45)
    #ax.set_xlim([x_space.min(), x_space.max()])
    #ax.set_xlim(0,1)
    
#lt.suptitle('Probability Histogram of date of Markov jump events', y=1.05, size=16)
ax.set_xlim(0, 1); 
plt.tight_layout();
fig.savefig('WAI_data/MJ_Dis_Clade2.3.4.4_monthly_destination_density.pdf')   # save the figure to file
plt.close(fig)    # close the figure window

# %%
freq_clade21 = pd.DataFrame(columns=['origin_location','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
for i, (origin) in enumerate(clade21.origin.unique()):
    x=clade21.loc[clade21.origin==origin,'dateinyear']
    res=stats.relfreq(x,numbins=12)
    freql = res.frequency.tolist()
    freq_clade21.loc[i] = [origin] + freql

freq_clade21

# %%
freq_clade21_dest = pd.DataFrame(columns=['dest_location','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
for i, (destination) in enumerate(clade21.destination.unique()):
    x=clade21.loc[clade21.destination==destination,'dateinyear']
    res=stats.relfreq(x,numbins=12)
    freql = res.frequency.tolist()
    freq_clade21_dest.loc[i] = [destination] + freql
    
freq_clade21_dest

# %%
freq_clade34_dest = pd.DataFrame(columns=['dest_location','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
for i, (destination) in enumerate(clade34.destination.unique()):
    x=clade34.loc[clade34.destination==destination,'dateinyear']
    res=stats.relfreq(x,numbins=12)
    freql = res.frequency.tolist()
    freq_clade34_dest.loc[i] = [destination] + freql

freq_clade34_dest

# %%
freq_clade34 = pd.DataFrame(columns=['origin_location','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'])
for i, (origin) in enumerate(clade34.origin.unique()):
    x=clade34.loc[clade34.origin==origin,'dateinyear']
    res=stats.relfreq(x,numbins=12)
    freql = res.frequency.tolist()
    freq_clade34.loc[i] = [origin] + freql

freq_clade34

# %%
birdProb21 = pd.read_csv('WAI_data/2.3.2.1_bird.csv')
birdProb21.head()

# %%
birdProb34 = pd.read_csv('WAI_data/2.3.4.4_bird.csv')
birdProb34.head()

# %%
from IPython.core.debugger import set_trace

# %%
corr_mj_bird_21_orig = pd.DataFrame(columns=['origin_location','bird_order','correlation_coefficient','p_value'])
i=0
for location in birdProb21.Location.unique():
    mj = freq_clade21.loc[freq_clade21.origin_location==location,['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]
    for bird in ['Accipitriformes','Anseriformes','Charadriiformes','Ciconiiformes','Falconiformes',
                 'Gruiformes','Passeriformes','Pelecaniformes','Procellariiformes','Suliformes']:
        birdProb = birdProb21.loc[birdProb21.Location==location,[bird+'1',bird+'2',bird+'3',bird+'4',bird+'5',bird+'6',bird+'7',bird+'8',bird+'9',bird+'10',bird+'11',bird+'12']]
        #cor = np.corrcoef(mj,birdProb)
        #set_trace()
        cor,p = stats.pearsonr(mj.values[0],birdProb.values[0])
        corr_mj_bird_21_orig.loc[i]= [location] + [bird] + [cor] + [p]
        #corr_mj_bird_21_orig.loc[i]= [location] + [bird] + [cor[0,1]] + [cor[0,0]]
        i=i+1
        
corr_mj_bird_21_orig

# %%
corr_mj_bird_21_dest = pd.DataFrame(columns=['dest_location','bird_order','correlation_coefficient','p_value'])
i=0
for location in birdProb21.Location.unique():
    mj = freq_clade21_dest.loc[freq_clade21_dest.dest_location==location,['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]
    for bird in ['Accipitriformes','Anseriformes','Charadriiformes','Ciconiiformes','Falconiformes',
                 'Gruiformes','Passeriformes','Pelecaniformes','Procellariiformes','Suliformes']:
        birdProb = birdProb21.loc[birdProb21.Location==location,[bird+'1',bird+'2',bird+'3',bird+'4',bird+'5',bird+'6',bird+'7',bird+'8',bird+'9',bird+'10',bird+'11',bird+'12']]
        cor,p = stats.pearsonr(mj.values[0],birdProb.values[0])
        corr_mj_bird_21_dest.loc[i]= [location] + [bird] + [cor] + [p]
        i=i+1
        #set_trace()
        
corr_mj_bird_21_dest

# %%
corr_mj_bird_34_orig = pd.DataFrame(columns=['origin_location','bird_order','correlation_coefficient','p_value'])
i=0
for location in birdProb34.Location.unique():
    mj = freq_clade34.loc[freq_clade34.origin_location==location,['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]
    for bird in ['Accipitriformes','Anseriformes','Charadriiformes','Ciconiiformes','Falconiformes',
                 'Gruiformes','Passeriformes','Pelecaniformes','Procellariiformes','Suliformes']:
        birdProb = birdProb34.loc[birdProb34.Location==location,[bird+'1',bird+'2',bird+'3',bird+'4',bird+'5',
                                                                 bird+'6',bird+'7',bird+'8',bird+'9',bird+'10',bird+'11',bird+'12']]
        
        cor,p = stats.pearsonr(mj.values[0],birdProb.values[0])
        corr_mj_bird_34_orig.loc[i]= [location] + [bird] + [cor] + [p]
        
        i=i+1
        
corr_mj_bird_34_orig

# %%
corr_mj_bird_34_dest = pd.DataFrame(columns=['dest_location','bird_order','correlation_coefficient','p_value'])
i=0
for location in birdProb34.Location.unique():
    mj = freq_clade34_dest.loc[freq_clade34_dest.dest_location==location,['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec']]
    for bird in ['Accipitriformes','Anseriformes','Charadriiformes','Ciconiiformes','Falconiformes',
                 'Gruiformes','Passeriformes','Pelecaniformes','Procellariiformes','Suliformes']:
        birdProb = birdProb34.loc[birdProb34.Location==location,[bird+'1',bird+'2',bird+'3',bird+'4',bird+'5',
                                                                 bird+'6',bird+'7',bird+'8',bird+'9',bird+'10',bird+'11',bird+'12']]
        cor,p = stats.pearsonr(mj.values[0],birdProb.values[0])
        corr_mj_bird_34_dest.loc[i]= [location] + [bird] + [cor] + [p]
        i=i+1
        
corr_mj_bird_34_dest

# %%
corr_mj_bird_34_dest.to_csv('WAI_data/corr_mj_bird_34_dest.csv')
corr_mj_bird_34_orig.to_csv('WAI_data/corr_mj_bird_34_orig.csv')
corr_mj_bird_21_orig.to_csv('WAI_data/corr_mj_bird_21_orig.csv')
corr_mj_bird_21_dest.to_csv('WAI_data/corr_mj_bird_21_dest.csv')
